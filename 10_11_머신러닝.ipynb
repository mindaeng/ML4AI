# %% [markdown]
# <a href="https://colab.research.google.com/github/mindaeng/ML4AI/blob/main/10_11_%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/nyc_weather_2018.csv
# Out:
# --2023-10-11 02:41:01--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/nyc_weather_2018.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4359847 (4.2M) [text/plain]
# Saving to: ‘nyc_weather_2018.csv’
#
# nyc_weather_2018.cs 100%[===================>]   4.16M  --.-KB/s    in 0.05s
#
# 2023-10-11 02:41:01 (75.8 MB/s) - ‘nyc_weather_2018.csv’ saved [4359847/4359847]

# %%
import pandas as pd

weather = pd.read_csv('nyc_weather_2018.csv',parse_dates=['date'])
weather
# Out:
#             date datatype            station attributes  value
# 0     2018-01-01     PRCP  GHCND:US1CTFR0039       ,,N,    0.0
# 1     2018-01-01     PRCP  GHCND:US1NJBG0015       ,,N,    0.0
# 2     2018-01-01     SNOW  GHCND:US1NJBG0015       ,,N,    0.0
# 3     2018-01-01     PRCP  GHCND:US1NJBG0017       ,,N,    0.0
# 4     2018-01-01     SNOW  GHCND:US1NJBG0017       ,,N,    0.0
# ...          ...      ...                ...        ...    ...
# 78775 2018-12-31     WDF5  GHCND:USW00094789       ,,W,  130.0
# 78776 2018-12-31     WSF2  GHCND:USW00094789       ,,W,    9.8
# 78777 2018-12-31     WSF5  GHCND:USW00094789       ,,W,   12.5
# 78778 2018-12-31     WT01  GHCND:USW00094789       ,,W,    1.0
# 78779 2018-12-31     WT02  GHCND:USW00094789       ,,W,    1.0
#
# [78780 rows x 5 columns]

# %% [markdown]
# # **Task 1**

# %%
snow_data = weather.query('datatype == "PRCP" and station.str.contains("S0007")')
snow_data
# Out:
#             date datatype            station attributes  value
# 79    2018-01-01     PRCP  GHCND:US1NYNS0007       ,,N,    0.0
# 311   2018-01-02     PRCP  GHCND:US1NYNS0007       ,,N,    0.0
# 545   2018-01-03     PRCP  GHCND:US1NYNS0007       ,,N,    0.0
# 788   2018-01-04     PRCP  GHCND:US1NYNS0007       ,,N,    4.1
# 1044  2018-01-05     PRCP  GHCND:US1NYNS0007       ,,N,   18.0
# ...          ...      ...                ...        ...    ...
# 77762 2018-12-27     PRCP  GHCND:US1NYNS0007       ,,N,    0.0
# 77974 2018-12-28     PRCP  GHCND:US1NYNS0007       ,,N,    4.3
# 78191 2018-12-29     PRCP  GHCND:US1NYNS0007       ,,N,   25.9
# 78408 2018-12-30     PRCP  GHCND:US1NYNS0007       ,,N,    0.3
# 78641 2018-12-31     PRCP  GHCND:US1NYNS0007       ,,N,    0.0
#
# [349 rows x 5 columns]

# %%
snow_data.count()
# Out:
# date          349
# datatype      349
# station       349
# attributes    349
# value         349
# dtype: int64

# %%
weather['attributes'].unique()
# Out:
# array([',,N,', 'T,,N,', ',,7,0700', ',,7,', 'T,,7,0700', ',,7,0800',
#        ',,W,', ',,W,2400', 'H,,S,', 'T,,W,2400', 'T,,7,', 'T,,N,0700',
#        'T,,W,', ',I,N,', ',Z,W,', 'T,I,N,', ',G,7,0800', ',,Z,',
#        ',,N,0700', ',Z,7,0700', ',Z,7,', ',,Z,0700', ',L,N,', ',,7,0630',
#        'T,,7,0630', ',S,W,2400'], dtype=object)

# %%
weather_attributes = weather.groupby('attributes').count()

# %%
weather_attributes.sort_values(by='value',ascending=False)
# Out:
#              date  datatype  station  value
# attributes
# ,,N,        34153     34153    34153  34153
# ,,W,        21241     21241    21241  21241
# ,,7,0700     8534      8534     8534   8534
# ,,W,2400     6641      6641     6641   6641
# ,,7,         2679      2679     2679   2679
# T,,N,        1886      1886     1886   1886
# H,,S,        1095      1095     1095   1095
# ,,7,0800     1034      1034     1034   1034
# ,,7,0630      715       715      715    715
# T,,W,2400     293       293      293    293
# T,,W,         250       250      250    250
# T,,7,0700     137       137      137    137
# T,,7,          50        50       50     50
# ,L,N,          29        29       29     29
# ,,Z,            7         7        7      7
# ,Z,7,0700       6         6        6      6
# T,,7,0630       6         6        6      6
# ,I,N,           5         5        5      5
# ,Z,W,           4         4        4      4
# ,,N,0700        4         4        4      4
# T,,N,0700       3         3        3      3
# T,I,N,          2         2        2      2
# ,Z,7,           2         2        2      2
# ,,Z,0700        2         2        2      2
# ,G,7,0800       1         1        1      1
# ,S,W,2400       1         1        1      1

# %% [markdown]
# # **Task 2**

# %%
# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/dirty_data.csv

# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/fb_2018.csv

# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/fb_week_of_may_20_per_minute.csv

# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/melted_stock_data.csv

# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/nyc_weather_2018.csv

# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/stocks.db

# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/weather.db

# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/weather_by_station.csv

# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/weather_stations.csv

# !mkdir data

# !mv *.* data
# Out:
# --2023-10-11 02:18:53--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/dirty_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46422 (45K) [text/plain]
# Saving to: ‘dirty_data.csv’
#
# dirty_data.csv      100%[===================>]  45.33K  --.-KB/s    in 0.01s
#
# 2023-10-11 02:18:53 (4.34 MB/s) - ‘dirty_data.csv’ saved [46422/46422]
#
# --2023-10-11 02:18:53--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/fb_2018.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12008 (12K) [text/plain]
# Saving to: ‘fb_2018.csv.2’
#
# fb_2018.csv.2       100%[===================>]  11.73K  --.-KB/s    in 0s
#
# 2023-10-11 02:18:53 (99.6 MB/s) - ‘fb_2018.csv.2’ saved [12008/12008]
#
# --2023-10-11 02:18:53--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/fb_week_of_may_20_per_minute.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 105385 (103K) [text/plain]
# Saving to: ‘fb_week_of_may_20_per_minute.csv’
#
# fb_week_of_may_20_p 100%[===================>] 102.92K  --.-KB/s    in 0.01s
#
# 2023-10-11 02:18:53 (7.96 MB/s) - ‘fb_week_of_may_20_per_minute.csv’ saved [105385/105385]
#
# --2023-10-11 02:18:53--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/melted_stock_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 214127 (209K) [text/plain]
# Saving to: ‘melted_stock_data.csv’
#
# melted_stock_data.c 100%[===================>] 209.11K  --.-KB/s    in 0.02s
#
# 2023-10-11 02:18:53 (10.7 MB/s) - ‘melted_stock_data.csv’ saved [214127/214127]
#
# --2023-10-11 02:18:53--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/nyc_weather_2018.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4359847 (4.2M) [text/plain]
# Saving to: ‘nyc_weather_2018.csv.1’
#
# nyc_weather_2018.cs 100%[===================>]   4.16M  --.-KB/s    in 0.06s
#
# 2023-10-11 02:18:54 (73.6 MB/s) - ‘nyc_weather_2018.csv.1’ saved [4359847/4359847]
#
# --2023-10-11 02:18:54--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/stocks.db
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 311296 (304K) [application/octet-stream]
# Saving to: ‘stocks.db’
#
# stocks.db           100%[===================>] 304.00K  --.-KB/s    in 0.03s
#
# 2023-10-11 02:18:54 (11.1 MB/s) - ‘stocks.db’ saved [311296/311296]
#
# --2023-10-11 02:18:54--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/weather.db
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4911104 (4.7M) [application/octet-stream]
# Saving to: ‘weather.db’
#
# weather.db          100%[===================>]   4.68M  --.-KB/s    in 0.05s
#
# 2023-10-11 02:18:55 (87.6 MB/s) - ‘weather.db’ saved [4911104/4911104]
#
# --2023-10-11 02:18:55--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/weather_by_station.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5429018 (5.2M) [text/plain]
# Saving to: ‘weather_by_station.csv’
#
# weather_by_station. 100%[===================>]   5.18M  --.-KB/s    in 0.06s
#
# 2023-10-11 02:18:55 (91.1 MB/s) - ‘weather_by_station.csv’ saved [5429018/5429018]
#
# --2023-10-11 02:18:55--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/weather_stations.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19523 (19K) [text/plain]
# Saving to: ‘weather_stations.csv’
#
# weather_stations.cs 100%[===================>]  19.07K  --.-KB/s    in 0s
#
# 2023-10-11 02:18:55 (38.4 MB/s) - ‘weather_stations.csv’ saved [19523/19523]

# %%
# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/fb_2018.csv
# Out:
# --2023-10-11 02:09:04--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/fb_2018.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12008 (12K) [text/plain]
# Saving to: ‘fb_2018.csv.1’
#
# fb_2018.csv.1       100%[===================>]  11.73K  --.-KB/s    in 0s
#
# 2023-10-11 02:09:04 (59.2 MB/s) - ‘fb_2018.csv.1’ saved [12008/12008]

# %%
import numpy as np
import pandas as pd

fb = pd.read_csv('fb_2018.csv', index_col='date', parse_dates=True).assign(
    trading_volume=lambda x: pd.cut(x.volume, bins=3, labels=['low', 'med', 'high'])
)
fb.head()
# Out:
#               open    high       low   close    volume trading_volume
# date
# 2018-01-02  177.68  181.58  177.5500  181.42  18151903            low
# 2018-01-03  181.88  184.78  181.3300  184.67  16886563            low
# 2018-01-04  184.90  186.21  184.0996  184.33  13880896            low
# 2018-01-05  185.59  186.90  184.9300  186.85  13574535            low
# 2018-01-08  187.20  188.90  186.3300  188.28  17994726            low

# %%
fb.sort_values(by='volume', ascending=False)
# Out:
#               open    high     low   close     volume trading_volume
# date
# 2018-07-26  174.89  180.13  173.75  176.26  169803668           high
# 2018-03-20  167.47  170.20  161.95  168.15  129851768           high
# 2018-03-26  160.82  161.10  149.02  160.06  126116634           high
# 2018-03-21  164.80  173.40  163.30  169.39  106598834            med
# 2018-03-19  177.01  177.17  170.06  172.56   88140060            med
# ...            ...     ...     ...     ...        ...            ...
# 2018-07-19  208.77  209.99  207.76  208.09   11350429            low
# 2018-07-16  207.50  208.72  206.84  207.23   11078209            low
# 2018-05-25  186.02  186.33  184.45  184.92   10965061            low
# 2018-01-10  186.94  187.89  185.63  187.84   10529894            low
# 2018-01-11  188.40  188.40  187.38  187.77    9588587            low
#
# [251 rows x 6 columns]

# %%
fb.groupby('trading_volume').mean()
# Out:
#                       open        high         low       close        volume
# trading_volume
# low             171.355565  173.461040  169.306252  171.431771  2.454721e+07
# med             175.818125  179.420000  172.107500  175.143750  7.907256e+07
# high            167.726667  170.476667  161.573333  168.156667  1.419240e+08

# %%
fb.groupby('trading_volume')['close'].agg(['min', 'max', 'mean'])
# Out:
#                    min     max        mean
# trading_volume
# low             124.06  214.67  171.431771
# med             152.22  217.50  175.143750
# high            160.06  176.26  168.156667

# %%
fb_agg = fb.groupby('trading_volume').agg({
    'open': 'mean',
    'high': ['min', 'max'],
    'low': ['min', 'max'],
    'close': 'mean'
})
fb_agg
# Out:
#                       open    high             low               close
#                       mean     min     max     min     max        mean
# trading_volume
# low             171.355565  129.74  216.20  123.02  212.60  171.431771
# med             175.818125  162.85  218.62  150.75  214.27  175.143750
# high            167.726667  161.10  180.13  149.02  173.75  168.156667

# %%
fb_agg.columns = ['_'.join(col_agg) for col_agg in fb_agg.columns]
fb_agg.head()
# Out:
#                  open_mean  high_min  high_max  low_min  low_max  close_mean
# trading_volume
# low             171.355565    129.74    216.20   123.02   212.60  171.431771
# med             175.818125    162.85    218.62   150.75   214.27  175.143750
# high            167.726667    161.10    180.13   149.02   173.75  168.156667

# %%
weather[weather.datatype == "PRCP"]
# Out:
#             date datatype            station attributes  value
# 0     2018-01-01     PRCP  GHCND:US1CTFR0039       ,,N,    0.0
# 1     2018-01-01     PRCP  GHCND:US1NJBG0015       ,,N,    0.0
# 3     2018-01-01     PRCP  GHCND:US1NJBG0017       ,,N,    0.0
# 6     2018-01-01     PRCP  GHCND:US1NJBG0018       ,,N,    0.0
# 9     2018-01-01     PRCP  GHCND:US1NJBG0023       ,,N,    0.0
# ...          ...      ...                ...        ...    ...
# 78736 2018-12-31     PRCP  GHCND:USW00054787       ,,W,   28.7
# 78743 2018-12-31     PRCP  GHCND:USW00094728   ,,W,2400   25.9
# 78751 2018-12-31     PRCP  GHCND:USW00094741       ,,W,   29.2
# 78760 2018-12-31     PRCP  GHCND:USW00094745   ,,W,2400   24.4
# 78768 2018-12-31     PRCP  GHCND:USW00094789   ,,W,2400   31.2
#
# [27228 rows x 5 columns]

# %%
weather = pd.read_csv('data/weather_by_station.csv', index_col='date', parse_dates=True)
weather.head()
# Out:
#            datatype            station  value                    station_name
# date
# 2018-01-01     PRCP  GHCND:US1CTFR0039    0.0           STAMFORD 4.2 S, CT US
# 2018-01-01     PRCP  GHCND:US1NJBG0015    0.0  NORTH ARLINGTON 0.7 WNW, NJ US
# 2018-01-01     SNOW  GHCND:US1NJBG0015    0.0  NORTH ARLINGTON 0.7 WNW, NJ US
# 2018-01-01     PRCP  GHCND:US1NJBG0017    0.0        GLEN ROCK 0.7 SSE, NJ US
# 2018-01-01     SNOW  GHCND:US1NJBG0017    0.0        GLEN ROCK 0.7 SSE, NJ US

# %%
weather.query('datatype == "PRCP"').groupby(level=0).mean().groupby(pd.Grouper(freq='Q')).sum().value.nlargest()
# Out:
# <ipython-input-103-cd5c521230e0>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   weather.query('datatype == "PRCP"').groupby(level=0).mean().groupby(pd.Grouper(freq='Q')).sum().value.nlargest()
# date
# 2018-09-30    546.518380
# 2018-12-31    473.972345
# 2018-03-31    364.885769
# 2018-06-30    334.893094
# Name: value, dtype: float64

# %%
db = weather.query('datatype == "PRCP"').groupby(level=0).mean()
# Out:
# <ipython-input-96-20cbae67d6b4>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   db = weather.query('datatype == "PRCP"').groupby(level=0).mean()

# %%
db.sort_values(by = "value", ascending=False)
# Out:
#        value
# 48207  147.6
# 45403  141.5
# 57888  141.2
# 48331  125.0
# 57864  112.0
# ...      ...
# 35837    0.0
# 35835    0.0
# 35833    0.0
# 35831    0.0
# 40726    0.0
#
# [27228 rows x 1 columns]

# %%
weather.query('datatype == "PRCP"').groupby(
    ['station', pd.Grouper(freq='Q')]
).sum().unstack().sample(5, random_state=1)
# Out:
# <ipython-input-104-d69a05b69bc4>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ).sum().unstack().sample(5, random_state=1)
#                        value
# date              2018-03-31 2018-06-30 2018-09-30 2018-12-31
# station
# GHCND:USC00308577      297.1      274.0      446.7      529.4
# GHCND:US1NYSF0092      385.7      254.4      471.7      470.2
# GHCND:US1NYWC0019      285.3      214.0      376.4      403.6
# GHCND:US1NYSF0089      314.9      259.6      342.6      383.8
# GHCND:USW00014732      308.8      301.7      452.8      432.2

# %%
central_park_weather = weather\
    .query('station == "GHCND:USW00094728"')\
    .pivot(index='date', columns='datatype', values='value')

# %%
central_park_weather['2018-10-01':'2018-10-03'].rolling('3D').agg(
    {'TMAX': 'max', 'TMIN': 'min', 'AWND': 'mean', 'PRCP': 'sum'}
).join( # join with original data for comparison
    central_park_weather[['TMAX', 'TMIN', 'AWND', 'PRCP']],
    lsuffix='_rolling'
).sort_index(axis=1)
# Out:
# datatype    AWND  AWND_rolling  PRCP  PRCP_rolling  TMAX  TMAX_rolling  TMIN  \
# date
# 2018-10-01   0.9      0.900000   0.0           0.0  24.4          24.4  17.2
# 2018-10-02   0.9      0.900000  17.5          17.5  25.0          25.0  18.3
# 2018-10-03   1.1      0.966667   0.0          17.5  23.3          25.0  17.2
#
# datatype    TMIN_rolling
# date
# 2018-10-01          17.2
# 2018-10-02          17.2
# 2018-10-03          17.2
