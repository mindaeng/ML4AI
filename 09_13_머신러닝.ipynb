# %% [markdown]
# <a href="https://colab.research.google.com/github/mindaeng/ML4AI/blob/main/09_13_%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Tasks1 for Today (09.13)**

# %%
import pandas as pd

teamdf = pd.DataFrame(
    {
        'name' : ['정서현','이강규','혜열정','지민경'],
        '취미': ['영화보기', '운동', '게임', '맛집탐방'],
        '국적': ['한국','한국','중국','한국'],
        '학과' : ['응통','기계','응통','응통'],
        '학번' : ['19','20','20','19'],
        '사는지역' : ['서울','서울','서울','인천']
    })

# %%
teamdf
# Out:
#   name    취미  국적  학과  학번 사는지역
# 0  정서현  영화보기  한국  응통  19   서울
# 1  이강규    운동  한국  기계  20   서울
# 2  혜열정    게임  중국  응통  20   서울
# 3  지민경  맛집탐방  한국  응통  19   인천

# %% [markdown]
# # **Tasks2 for Today (09.13)**

# %%
teamdf.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
teamdf.index.dtype
# Out:
# dtype('int64')

# %%
teamdf.shape
# Out:
# (4, 6)

# %%
teamdf.index = ['student1','student2','student3','student4']
teamdf
# Out:
#          name    취미  국적  학과  학번 사는지역
# student1  정서현  영화보기  한국  응통  19   서울
# student2  이강규    운동  한국  기계  20   서울
# student3  혜열정    게임  중국  응통  20   서울
# student4  지민경  맛집탐방  한국  응통  19   인천

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
teamdf.to_csv('0913_teamdf.csv', index=True)

# %%
data = pd.read_csv('0913_teamdf.csv')

# %%
data
# Out:
#   Unnamed: 0 name    취미  국적  학과  학번 사는지역
# 0   student1  정서현  영화보기  한국  응통  19   서울
# 1   student2  이강규    운동  한국  기계  20   서울
# 2   student3  혜열정    게임  중국  응통  20   서울
# 3   student4  지민경  맛집탐방  한국  응통  19   인천

# %%
data.set_index(data['Unnamed: 0'], inplace=False)
# Out:
#            Unnamed: 0 name    취미  국적  학과  학번 사는지역
# Unnamed: 0
# student1     student1  정서현  영화보기  한국  응통  19   서울
# student2     student2  이강규    운동  한국  기계  20   서울
# student3     student3  혜열정    게임  중국  응통  20   서울
# student4     student4  지민경  맛집탐방  한국  응통  19   인천

# %%
data
# Out:
#            Unnamed: 0 name    취미  국적  학과  학번 사는지역
# Unnamed: 0
# student1     student1  정서현  영화보기  한국  응통  19   서울
# student2     student2  이강규    운동  한국  기계  20   서울
# student3     student3  혜열정    게임  중국  응통  20   서울
# student4     student4  지민경  맛집탐방  한국  응통  19   인천
